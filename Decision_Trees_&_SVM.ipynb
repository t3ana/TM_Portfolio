# %%
#Task 1
#Plot Course vs Class Size Data // Denote three classes with color 
import numpy as np
import matplotlib.pyplot as plt 

#Import Data // Input features (x) and classes (y)
TeachingEval = read_csv('TeachingAssistantEvaluationDataSet.csv')
X = [TeachingEval['Course'], TeachingEval['Class Size']] 
Y = TeachingEval['Class Attribute']


X= np.asarray(X)
Y= np.asarray(Y)
X= X.T

#Create the Scatterplot 
plt.scatter(X[:,0],X[:,1],c=Y,s=30, cmap=plt.cm.Paired) 
  #X[:,0] contains Course making them x-values on the scattrplot 
  #X[:,1] contains Class Size making them y-values
  #c=Y notes which class each data point belongs to
ax=plt.gca()
xlim=ax.get_xlim()
ylim=ax.get_ylim()
xx=np.linspace(xlim[0],xlim[1])
yy=np.linspace(ylim[0],ylim[1])
XX,YY=np.meshgrid(xx,yy)
xy=np.vstack([XX.ravel(),YY.ravel()]).T

#Create Labels
plt.title('Course vs Class Size')
plt.xlabel('Course')
plt.ylabel('Class Size')
# Out:
# Text(0, 0.5, 'Class Size')

# %%
#Task 2
#Create a decision tree using all the features
from pandas import * 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
import graphviz 
from sklearn.tree import DecisionTreeClassifier

#Import Data // Input features (x) and classes (y)
TeachingEval = read_csv('TeachingAssistantEvaluationDataSet.csv')
X = [TeachingEval['Native English Speaker'],TeachingEval['Course Instructor'],TeachingEval['Course'],TeachingEval['Summer or Regular'],TeachingEval['Class Size']]  
Y = TeachingEval['Class Attribute']

X= np.asarray(X)
Y= np.asarray(Y)
X= X.T

#Make Decision Tree
TeachingEvalTree = tree.DecisionTreeClassifier(max_depth=6)
  #Adding a max depth to prevent tree from overfitting
TeachingEvalTree = TeachingEvalTree.fit(X,Y)
dot_data = tree.export_graphviz(TeachingEvalTree, out_file=None)
graph = graphviz.Source(dot_data)
graph

# %%
#Task 3
#Train a SVM on Course and Class Size // Use color to denote the classes
from os import readv
from pandas import *
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import svm 
from sklearn import preprocessing

#Import Data // Input features (x) and classes (y) 
#Create SVM // Choose Kernel
TeachingEval = read_csv('TeachingAssistantEvaluationDataSetBinaryClasses.csv')
X = [TeachingEval['Course'], TeachingEval['Class Size']]
Y = TeachingEval['Class Attribute']
clf=svm.SVC(kernel='rbf', gamma=.55)

X= np.asarray(X)
Y= np.asarray(Y)
X= X.T
clf.fit(X,Y)

#Plot SVM
plt.scatter(X[:,0],X[:,1],c=Y,s=30, cmap=plt.cm.Paired)
  #X[:,0] contains Course making them x-values on the scattrplot 
  #X[:,1] contains Class Size making them y-values
  #c=Y notes which class each data point belongs to
ax=plt.gca()
xlim=ax.get_xlim()
ylim=ax.get_ylim()
xx=np.linspace(xlim[0],xlim[1],30)
yy=np.linspace(ylim[0],ylim[1],30)
XX,YY=np.meshgrid(xx,yy)
xy=np.vstack([XX.ravel(),YY.ravel()]).T
Z=clf.decision_function(xy).reshape(XX.shape)
ax.contour(XX,YY,Z,colors='k',levels=[-1,0,1],alpha=0.5,linestyles=['--','-','--'])

# %%
#Task 4
#Train a decision tree // Use all features
from pandas import * 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
import graphviz 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

#Import Data // Input features (x) and classes (y) 
TeachingEval = read_csv('TeachingAssistantEvaluationDataSetBinaryClasses.csv')
X = [TeachingEval['Native English Speaker'],TeachingEval['Course Instructor'],TeachingEval['Course'],TeachingEval['Summer or Regular'],TeachingEval['Class Size']]   
Y = TeachingEval['Class Attribute']
X= np.asarray(X)
Y= np.asarray(Y)
X= X.T

#Train data on a 80/20 split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train.shape, Y_train.shape
X_test.shape, Y_test.shape

#Make Decision Tree
TeachingEvalTree = tree.DecisionTreeClassifier(max_depth=5)
  #Adding a max depth to prevent tree from overfitting
TeachingEvalTree = TeachingEvalTree.fit(X,Y)
dot_data = tree.export_graphviz(TeachingEvalTree, out_file=None)
graph = graphviz.Source(dot_data)
graph
