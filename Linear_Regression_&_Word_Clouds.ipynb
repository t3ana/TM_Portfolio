# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
import seaborn as seabornInstance
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
weatherPlace=pd.read_csv("WeatherPlacementData.csv", index_col=0)
weatherPlace.head()
# Out:
#                                      Summary  ...                 Daily Summary
# Formatted Date                                ...
# 2006-04-11 01:00:00.000 +0200       Overcast  ...         Foggy in the evening.
# 2006-04-13 07:00:00.000 +0200       Overcast  ...  Overcast throughout the day.
# 2006-04-04 00:00:00.000 +0200  Partly Cloudy  ...  Mostly cloudy until evening.
# 2006-04-05 00:00:00.000 +0200  Partly Cloudy  ...         Foggy in the morning.
#
# [4 rows x 11 columns]

# %%
weatherTest=pd.read_csv("WeatherTestData.csv", index_col=0)
weatherTest.head()
# Out:
#                                      Summary  ...                      Daily Summary
# Formatted Date                                ...
# 2006-04-01 00:00:00.000 +0200  Partly Cloudy  ...  Partly cloudy throughout the day.
# 2006-04-01 01:00:00.000 +0200  Partly Cloudy  ...  Partly cloudy throughout the day.
# 2006-04-01 02:00:00.000 +0200  Mostly Cloudy  ...  Partly cloudy throughout the day.
# 2006-04-01 03:00:00.000 +0200  Partly Cloudy  ...  Partly cloudy throughout the day.
# 2006-04-01 04:00:00.000 +0200  Mostly Cloudy  ...  Partly cloudy throughout the day.
#
# [5 rows x 11 columns]

# %%
text=weatherTest['Daily Summary'][11]
print(type(text))
# Out:
# <class 'str'>

# %%
wordcloud=WordCloud().generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text=" ".join(review for review in weatherTest['Daily Summary'])

# %%
STOPWORDS=set(STOPWORDS)
STOPWORDS.update(["throughout","starting","morning","day","night","evening","continuing","overnight","afternoon"])

# %%
wordcloud=WordCloud(stopwords=STOPWORDS, background_color="white").generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
weatherTest.plot(x='Temperature (C)', y='Apparent Temperature (C)', style='*')
